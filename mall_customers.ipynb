# %%
#including important libararies
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
#%matplotlib inline   #if we dont use it then there will be a need to write plt.show

# %%
df = pd.read_csv('data/Mall_Customers.csv')
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
#correcting the miss spelled column from genre to gender

# %%
df=df.rename({'Genre':'Gender'},axis=1)

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
#gender is in object

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
#dropping unnecessary column

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
#analysing our data with some visualisation

# %%
column=['Age','Annual Income (k$)','Spending Score (1-100)']

# %%
sns.distplot(df['Age'])    
plt.show()
# Out:
# C:\Users\simran\AppData\Local\Temp\ipykernel_5332\1735818501.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])

# %%
sns.distplot(df['Annual Income (k$)'])
# Out:
# C:\Users\simran\AppData\Local\Temp\ipykernel_5332\1994242243.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Annual Income (k$)'])
# <Axes: xlabel='Annual Income (k$)', ylabel='Density'>

# %%
sns.distplot(df['Spending Score (1-100)'])
# Out:
# C:\Users\simran\AppData\Local\Temp\ipykernel_5332\3737231236.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Spending Score (1-100)'])
# <Axes: xlabel='Spending Score (1-100)', ylabel='Density'>

# %%
sns.histplot(df['Gender'])
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %%
sns.violinplot(x=df['Age'],y=df['Gender'])
# Out:
# <Axes: xlabel='Age', ylabel='Gender'>

# %%
sns.violinplot(x=df['Annual Income (k$)'],y=df['Gender'])
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Gender'>

# %%
sns.violinplot(x=df['Spending Score (1-100)'],y=df['Gender'])
# Out:
# <Axes: xlabel='Spending Score (1-100)', ylabel='Gender'>

# %%
#Analysing the data on the basis of different age categories

# %%
age_18_25=df.Age[(df.Age>=18)&(df.Age<=25)]
age_26_35=df.Age[(df.Age>=26)&(df.Age<=35)]
age_36_45=df.Age[(df.Age>=36)&(df.Age<=45)]
age_46_55=df.Age[(df.Age>=46)&(df.Age<=55)]
age_55above=df.Age[df.Age >=56]

agex=["18-25","26-35","36-45","46-55","55+"]
agey=[len(age_18_25.values),len(age_26_35.values),len(age_36_45.values),len(age_46_55.values),len(age_55above.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=agex,y=agey,palette="mako")
plt.title("Number of Customer and Ages")
plt.xlabel("Age")
plt.ylabel("Number of Customer")
plt.show()
# Out:
# C:\Users\simran\AppData\Local\Temp\ipykernel_5332\4048766029.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=agex,y=agey,palette="mako")

# %%
sns.relplot(x="Annual Income (k$)",y="Spending Score (1-100)",data=df)

# %%
ss_1_20=df['Spending Score (1-100)'][(df["Spending Score (1-100)"]>=1)&(df["Spending Score (1-100)"]<=20)]
ss_21_40=df['Spending Score (1-100)'][(df["Spending Score (1-100)"]>=21)&(df["Spending Score (1-100)"]<=40)]
ss_41_60=df['Spending Score (1-100)'][(df["Spending Score (1-100)"]>=41)&(df["Spending Score (1-100)"]<=60)]
ss_61_80=df['Spending Score (1-100)'][(df["Spending Score (1-100)"]>=61)&(df["Spending Score (1-100)"]<=80)]
ss_81_100=df['Spending Score (1-100)'][(df["Spending Score (1-100)"]>=81)&(df["Spending Score (1-100)"]<=100)]

ssx=["1-20","21-40","41-60","61-80","81-100"]
ssy= [len(ss_1_20),len(ss_21_40.values),len(ss_41_60.values),len(ss_61_80.values),len(ss_81_100.values)]
plt.figure(figsize=(15,6))
sns.barplot(x=ssx,y=ssy,palette="mako")
plt.title("Spending Score")
plt.xlabel("Score")
plt.ylabel("Number of Customer Having the Score"  )
plt.show()
# Out:
# C:\Users\simran\AppData\Local\Temp\ipykernel_5332\1212012600.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ssx,y=ssy,palette="mako")

# %%
ai0_30=df["Annual Income (k$)"][(df["Annual Income (k$)"]>=0)&(df["Annual Income (k$)"]<=30)]
ai31_60=df["Annual Income (k$)"][(df["Annual Income (k$)"]>=31)&(df["Annual Income (k$)"]<=60)]
ai61_90=df["Annual Income (k$)"][(df["Annual Income (k$)"]>=61)&(df["Annual Income (k$)"]<=90)]
ai91_120=df["Annual Income (k$)"][(df["Annual Income (k$)"]>=91)&(df["Annual Income (k$)"]<=120)]
ai121_150=df["Annual Income (k$)"][(df["Annual Income (k$)"]>=121)&(df["Annual Income (k$)"]<=150)]

alx=["$ 0-30,000","$ 30,001-60,000","$ 60,001-90,000","$ 90,001-120,000","$ 120,001-150,000"]
aly=[len(ai0_30.values),len(ai31_60.values),len(ai61_90.values),len(ai91_120.values),len(ai121_150.values)]
plt.figure(figsize=(15,6))
sns.barplot(x=alx,y=aly,palette="mako")
plt.title("Spending Score")
plt.xlabel("Score")
plt.ylabel("Number of Customer Having the Score"  )
plt.show()
# Out:
# C:\Users\simran\AppData\Local\Temp\ipykernel_5332\1429576169.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=alx,y=aly,palette="mako")

# %%
## converting the clusters
from sklearn.cluster import KMeans

# %%
plt.scatter(df['Age'],df['Spending Score (1-100)'])

# %%
x1=df.loc[:,["Age","Spending Score (1-100)"]].values

from sklearn.cluster import KMeans            #sklearn is library and cluster is module inside it and kmeans is the algorithm
wcss=[] #within-cluster Sum of Square
for k in range(1,11):
    kmeans=KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(x1)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))
plt.grid
plt.plot(range(1,11),wcss,linewidth=2,color="red",marker="8")
plt.xlabel("K Value")
plt.ylabel("WCSS")
plt.show()
# Out:
# c:\Users\simran\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\simran\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\simran\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
x1
# Out:
# array([[19, 39],
#        [21, 81],
#        [20,  6],
#        [23, 77],
#        [31, 40],
#        [22, 76],
#        [35,  6],
#        [23, 94],
#        [64,  3],
#        [30, 72],
#        [67, 14],
#        [35, 99],
#        [58, 15],
#        [24, 77],
#        [37, 13],
#        [22, 79],
#        [35, 35],
#        [20, 66],
#        [52, 29],
#        [35, 98],
#        [35, 35],
#        [25, 73],
#        [46,  5],
#        [31, 73],
#        [54, 14],
#        [29, 82],
#        [45, 32],
#        [35, 61],
#        [40, 31],
#        [23, 87],
#        [60,  4],
#        [21, 73],
#        [53,  4],
#        [18, 92],
#        [49, 14],
#        [21, 81],
#        [42, 17],
#        [30, 73],
#        [36, 26],
#        [20, 75],
#        [65, 35],
#        [24, 92],
#        [48, 36],
#        [31, 61],
#        [49, 28],
#        [24, 65],
#        [50, 55],
#        [27, 47],
#        [29, 42],
#        [31, 42],
#        [49, 52],
#        [33, 60],
# ...

# %%
import warnings

# To suppress all warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=FutureWarning)

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(x1)
    print(kmeans.inertia_)
# Out:
# 171535.5
# 75949.15601023017
# 45840.67661610868
# 28165.583566629342
# 23810.46223307136
# 19506.941015125223
# 15523.684014328752
# 13091.763404723932
# 11509.952265219918
# 10170.836243386242

# %%
x1
# Out:
# array([[19, 39],
#        [21, 81],
#        [20,  6],
#        [23, 77],
#        [31, 40],
#        [22, 76],
#        [35,  6],
#        [23, 94],
#        [64,  3],
#        [30, 72],
#        [67, 14],
#        [35, 99],
#        [58, 15],
#        [24, 77],
#        [37, 13],
#        [22, 79],
#        [35, 35],
#        [20, 66],
#        [52, 29],
#        [35, 98],
#        [35, 35],
#        [25, 73],
#        [46,  5],
#        [31, 73],
#        [54, 14],
#        [29, 82],
#        [45, 32],
#        [35, 61],
#        [40, 31],
#        [23, 87],
#        [60,  4],
#        [21, 73],
#        [53,  4],
#        [18, 92],
#        [49, 14],
#        [21, 81],
#        [42, 17],
#        [30, 73],
#        [36, 26],
#        [20, 75],
#        [65, 35],
#        [24, 92],
#        [48, 36],
#        [31, 61],
#        [49, 28],
#        [24, 65],
#        [50, 55],
#        [27, 47],
#        [29, 42],
#        [31, 42],
#        [49, 52],
#        [33, 60],
# ...

# %%
kmeans=KMeans(n_clusters=4)
label_age=kmeans.fit_predict(x1)

# %%
label_age
# Out:
# array([0, 1, 2, 1, 0, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 0, 0, 2, 1, 0, 1,
#        2, 1, 2, 1, 2, 0, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 3, 1, 3, 0,
#        2, 0, 3, 0, 0, 0, 3, 0, 0, 3, 3, 3, 3, 3, 0, 3, 3, 0, 3, 3, 3, 0,
#        3, 3, 0, 0, 3, 3, 3, 3, 3, 0, 3, 0, 0, 3, 3, 0, 3, 3, 0, 3, 3, 0,
#        0, 3, 3, 0, 3, 0, 0, 0, 3, 0, 3, 0, 0, 3, 3, 0, 3, 0, 3, 3, 3, 3,
#        3, 0, 0, 0, 0, 0, 3, 3, 3, 3, 0, 0, 0, 1, 0, 1, 3, 1, 2, 1, 2, 1,
#        0, 1, 2, 1, 2, 1, 2, 1, 2, 1, 0, 1, 2, 1, 3, 1, 2, 1, 2, 1, 2, 1,
#        2, 1, 2, 1, 2, 1, 3, 1, 2, 1, 2, 1, 2, 1, 2, 0, 2, 1, 2, 1, 2, 1,
#        2, 1, 2, 1, 2, 1, 2, 1, 0, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1,
#        2, 1])

# %%
df['cluster_age']=label_age

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    cluster_age
# 0            0
# 1            1
# 2            2
# 3            1
# 4            0

# %%
print(kmeans.cluster_centers_)
# Out:
# [[27.61702128 49.14893617]
#  [30.1754386  82.35087719]
#  [43.29166667 15.02083333]
#  [55.70833333 48.22916667]]

# %%
x1
# Out:
# array([[19, 39],
#        [21, 81],
#        [20,  6],
#        [23, 77],
#        [31, 40],
#        [22, 76],
#        [35,  6],
#        [23, 94],
#        [64,  3],
#        [30, 72],
#        [67, 14],
#        [35, 99],
#        [58, 15],
#        [24, 77],
#        [37, 13],
#        [22, 79],
#        [35, 35],
#        [20, 66],
#        [52, 29],
#        [35, 98],
#        [35, 35],
#        [25, 73],
#        [46,  5],
#        [31, 73],
#        [54, 14],
#        [29, 82],
#        [45, 32],
#        [35, 61],
#        [40, 31],
#        [23, 87],
#        [60,  4],
#        [21, 73],
#        [53,  4],
#        [18, 92],
#        [49, 14],
#        [21, 81],
#        [42, 17],
#        [30, 73],
#        [36, 26],
#        [20, 75],
#        [65, 35],
#        [24, 92],
#        [48, 36],
#        [31, 61],
#        [49, 28],
#        [24, 65],
#        [50, 55],
#        [27, 47],
#        [29, 42],
#        [31, 42],
#        [49, 52],
#        [33, 60],
# ...

# %%
plt.scatter(x1[:,0],x1[:,1],c=kmeans.labels_,cmap='rainbow')    #kmeans.labels= Assigns a color to each point based on the cluster label it belongs to
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],color="black")
plt.title("Cluster of Customers")
plt.xlabel('Age')
plt.ylabel('Spreading score(1-100)')

plt.show()

# %%
# Assuming df is your DataFrame
filtered_data_age = df[(df['Age'] >= 20) & (df['Age'] <= 40) & (df['Spending Score (1-100)'] > 70)]


filtered_data_age.shape
# Out:
# (53, 6)

# %%
filtered_data_age
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 1             2    Male   21                  15                      81
# 3             4  Female   23                  16                      77
# 5             6  Female   22                  17                      76
# 7             8  Female   23                  18                      94
# 9            10  Female   30                  19                      72
# 11           12  Female   35                  19                      99
# 13           14  Female   24                  20                      77
# 15           16    Male   22                  20                      79
# 19           20  Female   35                  23                      98
# 21           22    Male   25                  24                      73
# 23           24    Male   31                  25                      73
# 25           26    Male   29                  28                      82
# ...

# %%
x2=df.loc[:,["Annual Income (k$)","Spending Score (1-100)"]].values

from sklearn.cluster import KMeans
wcss=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(x2)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))
plt.grid
plt.plot(range(1,11),wcss,linewidth=2,color="red",marker="8")
plt.xlabel("K Value")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans=KMeans(n_clusters=5)
label_income=kmeans.fit_predict(x2)

# %%
x2
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
plt.scatter(x2[:,0],x2[:,1],c=kmeans.labels_,cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],color="black")
plt.title("Cluster of Customers")
plt.xlabel('Annual Income')
plt.ylabel('Spreading score(1-100)')
plt.grid(True)
plt.show()

# %%
# Assuming df is your DataFrame
filtered_data_income = df[(df['Annual Income (k$)'] >= 65) & (df['Spending Score (1-100)'] > 60)]


filtered_data_income.shape
# Out:
# (39, 6)

# %%
filtered_data_income
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 123         124    Male   39                  69                      91
# 125         126  Female   31                  70                      77
# 127         128    Male   40                  71                      95
# 129         130    Male   38                  71                      75
# 131         132    Male   39                  71                      75
# 133         134  Female   31                  72                      71
# 135         136  Female   29                  73                      88
# 137         138    Male   32                  73                      73
# 139         140  Female   35                  74                      72
# 141         142    Male   32                  75                      93
# 143         144  Female   32                  76                      87
# 145         146    Male   28                  77                      97
# ...
